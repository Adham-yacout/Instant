# %%
import pandas as pd

# %%
x=pd.read_excel("Book1.xlsx",sheet_name=None)
x
# Out:
# {'Sheet1':     House Age (years)  Distance to Station (meters)  Price per Square Foot  \
#  0                32.0                      84.87882                   75.8
#  1                19.5                     306.59470                   84.4
#  2                13.3                     561.98450                   94.6
#  3                13.3                     561.98450                  109.6
#  4                 5.0                     390.56840                   86.2
#  5                 7.1                    2175.03000                   64.2
#  6                34.5                     623.47310                   80.6
#  7                20.3                     287.60250                   93.4
#  8                31.7                    5512.03800                   37.6
#  9                17.9                    1783.18000                   44.2
#  10               34.8                     405.21340                   82.8
# ...

# %%
#notes Data Frames are data displayed in a format as a table. Data Frames can have different types of data inside it
school={
    'Name':["adham","ahmed","sara"],
    'id':["6740","6741","6742"]
}
df = pd.DataFrame(school) #created a dataframe
df.to_csv("C:/Users/adham/Downloads/school.csv")
schoolnew={
    'Name':["khaled","shokry","salma"],
    'id':["6755","6744","6747"]
}
df2=pd.DataFrame(schoolnew)
df2.to_csv("C:/Users/adham/Downloads/school.csv",header=False,mode='a')
